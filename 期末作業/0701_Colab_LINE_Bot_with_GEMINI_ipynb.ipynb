# %% [markdown]
# <a href="https://colab.research.google.com/github/hsin0606/MachineLearning/blob/main/%E6%9C%9F%E6%9C%AB%E4%BD%9C%E6%A5%AD/0701_Colab_LINE_Bot_with_GEMINI_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install Flask pyngrok line-bot-sdk requests --quiet
# !pip install google-genai --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.5/819.5 kB 21.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.6/165.6 kB 8.1 MB/s eta 0:00:00

# %%
from google.colab import userdata

ngrok_authtoken = userdata.get('NGROK_AUTHTOKEN')
line_channel_access_token = userdata.get('LINE_CHANNEL_ACCESS_TOKEN')
line_channel_secret = userdata.get('LINE_CHANNEL_SECRET')
gemini_api_key = userdata.get('GEMINI_API_KEY')
port = 5051

# %%
import os
from pyngrok import ngrok

# %%
ngrok.kill()

# %%
import requests

ngrok.set_auth_token(ngrok_authtoken)
tunnel = ngrok.connect(5051, name="linebot_tunnel")
webhook_url = tunnel.public_url

print(f"Ngrok URL: {webhook_url}")

# 自動更新 LINE Webhook URL
def update_line_webhook(webhook_url):
    """使用 LINE Messaging API 更新 Webhook URL"""
    url = "https://api.line.me/v2/bot/channel/webhook/endpoint"
    headers = {
        "Authorization": f"Bearer {line_channel_access_token}",
        "Content-Type": "application/json"
    }
    data = {
        "endpoint": webhook_url
    }

    response = requests.put(url, headers=headers, json=data)

    if response.status_code == 200:
        print(f"✅ LINE Webhook URL 已自動更新為：{webhook_url}")
        return True
    else:
        print(f"❌ 更新失敗：{response.status_code} - {response.text}")
        return False

# 執行更新
update_line_webhook(webhook_url)
# Out:
# Ngrok URL: https://colonize-lego-runt.ngrok-free.dev
# ✅ LINE Webhook URL 已自動更新為：https://colonize-lego-runt.ngrok-free.dev
# True

# %%
from google import genai

client = genai.Client(api_key=gemini_api_key)

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="什麼是AI AGENT？"
)
print(response.text)
# Out:
# AI Agent (AI 代理) 是一個非常重要的概念，尤其在當前AI發展熱潮中，它代表著AI從單純的工具向更自主、更智能的實體演進。
#
# 簡單來說，**AI Agent 是一個能夠感知環境、做出決策並採取行動以達成特定目標的自主（autonomous）軟體或硬體實體。**
#
# 它就像一個迷你的人工智能「工作者」，被賦予了某種程度的獨立思考和執行能力。
#
# ### AI Agent 的核心特徵：
#
# AI Agent 的運作可以用一個「感知-思考-行動」的循環來概括。
#
# 1.  **感知 (Perception)：**
#     *   Agent 必須能夠從其運作的環境中收集信息。這可以透過各種「感測器」來實現，例如：
#         *   **軟體環境：** 接收API的數據、讀取文件、監聽事件、分析文本輸入、解析網頁內容等。
#         *   **實體環境：** 透過攝影機、麥克風、觸摸感測器、雷達等獲取視覺、聽覺、觸覺信息。
#
# 2.  **思考/決策 (Deliberation/Decision-making)：**
#     *   Agent 會處理它所感知到的信息，運用其內建的智能（例如規則、演算法、機器學習模型，特別是大型語言模型LLM）來理解環境狀態、評估選項、規劃步驟並做出決策。
#     *   這一步是 Agent 的「大腦」，決定了它下一步將如何行動。
#
# 3.  **行動 (Action)：**
#     *   根據其決策，Agent 會在其環境中執行操作，以嘗試達成其目標。這可以透過各種「執行器」來實現，例如：
#         *   **軟體環境：** 調用API、寫入文件、發送郵件、生成程式碼、控制其他軟體、與用戶對話等。
#         *   **實體環境：** 移動手臂、行走、說話、操作工具等。
#
# 4.  **環境 (Environment)：**
#     *   Agent 在其中感知和行動的上下文。這可以是虛擬的（如電腦系統、網絡、模擬器）或物理的（如現實世界）。
#
# 5.  **目標 (Goals)：**
# ...

# %%
def stateless_query(payload):
    response = client.models.generate_content(
        model="gemini-2.5-flash",
        contents=payload
    )
    return response.text

# %%
result = stateless_query("簡介明新科技大學")
print(result)
# Out:
# **明新科技大學（Ming Hsin University of Science and Technology, MHUST）** 是一所位於台灣新竹縣新豐鄉的知名私立科技大學，以其悠久的歷史、務實的教學理念和緊密的產業連結而聞名。
#
# **主要特色與簡介：**
#
# 1.  **歷史悠久與發展：**
#     *   創立於1966年，前身為「明新工業專科學校」，是台灣最早成立的私立工專之一，見證了台灣技職教育的發展歷程。
#     *   歷經數十年的發展與轉型，於2002年正式升格為科技大學。
#
# 2.  **地理位置優越：**
#     *   學校毗鄰新竹科學園區，與高科技產業鏈緊密結合。此地理優勢為學生提供了豐富的實習與就業機會，特別是在工程、資訊和管理等相關領域。
#
# 3.  **教學理念與學術特色：**
#     *   **校訓：「敬業樂群」**，致力於培育具備專業技能、實務經驗與人文素養的產業人才。
#     *   **課程設計：** 強調「理論與實務並重」，注重學生的動手能力與產業接軌，培養畢業生具備立即上工的競爭力。
#     *   **學院與學制：** 設有工學院、管理學院、服務產業學院及人文社會暨設計學院等多個學院，提供學士、碩士等多元學制，涵蓋了工程、資訊、管理、觀光、餐飲、設計等熱門領域。
#
# 4.  **產業連結與就業優勢：**
#     *   與眾多企業建立產學合作關係，提供學生校外實習、專題研究及就業輔導。
#     *   長期以來，明新科大以畢業生高就業率和深受企業界肯定而聞名，是許多企業在招募基層和中階人才時的重要選擇。
#
# 5.  **校園環境與資源：**
#     *   校園設施現代化，教學資源豐富，包括專業實驗室、實習工廠、圖書館、體育設施等，提供學生優質的學習與生活環境。
#
# **總體而言，明新科技大學是一所歷史悠久、辦學績效卓著，且以培育產業所需實務人才為導向的優質科技大學，是桃竹苗地區重要的技職人才培育基地。**

# %%
from flask import Flask, request, abort

from linebot.v3 import (
    WebhookHandler
)
from linebot.v3.exceptions import (
    InvalidSignatureError
)
from linebot.v3.messaging import (
    Configuration,
    ApiClient,
    MessagingApi,
    ReplyMessageRequest,
    TextMessage,
)
from linebot.v3.webhooks import (
    MessageEvent,
    TextMessageContent,
)

app = Flask(__name__)

configuration = Configuration(access_token=line_channel_access_token)
handler = WebhookHandler(line_channel_secret)


@app.route("/", methods=['POST'])
def callback():
    # get X-Line-Signature header value
    signature = request.headers['X-Line-Signature']

    # get request body as text
    body = request.get_data(as_text=True)
    print("BODY: ", body)
    app.logger.info("Request body: " + body)

    # handle webhook body
    try:
        handler.handle(body, signature)
    except InvalidSignatureError:
        app.logger.info("Invalid signature. Please check your channel access token/channel secret.")
        abort(400)

    return 'OK'


@handler.add(MessageEvent, message=TextMessageContent)
def handle_message(event):
    text = event.message.text
    with ApiClient(configuration) as api_client:
        line_bot_api = MessagingApi(api_client)
        if text.startswith('AI '):     #這邊有限定使用AI 執行結果才會使用gimini回答
            prompt = text[3:]
            reply_text = stateless_query(prompt)
            line_bot_api.reply_message_with_http_info(
                ReplyMessageRequest(
                    reply_token=event.reply_token,
                    messages=[TextMessage(text=reply_text)]
                )
            )

        else:
            line_bot_api.reply_message_with_http_info(
                ReplyMessageRequest(
                    reply_token=event.reply_token,
                    messages=[TextMessage(text=event.message.text),
                        TextMessage(text=event.message.text)]
                )
            )

if __name__ == "__main__":
    app.run(port=port)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5051
# INFO:werkzeug:Press CTRL+C to quit
